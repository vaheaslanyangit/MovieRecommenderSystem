# %%
import pandas as pd

# %% [markdown]
# # Data Exploration and Preprocessing

# %%
# %pip install pandas

# %%
import pandas as pd

# %%
movies=pd.read_csv('dataset.csv')

# %%
movies.head(10)
# Out:
#        id                        title                     genre  \
# 0     278     The Shawshank Redemption               Drama,Crime
# 1   19404  Dilwale Dulhania Le Jayenge      Comedy,Drama,Romance
# 2     238                The Godfather               Drama,Crime
# 3     424             Schindler's List         Drama,History,War
# 4     240       The Godfather: Part II               Drama,Crime
# 5  667257            Impossible Things              Family,Drama
# 6     129                Spirited Away  Animation,Family,Fantasy
# 7  730154               Your Eyes Tell             Romance,Drama
# 8  372754     Dou kyu sei – Classmates         Romance,Animation
# 9  372058                   Your Name.   Romance,Animation,Drama
#
#   original_language                                           overview  \
# 0                en  Framed in the 1940s for the double murder of h...
# 1                hi  Raj is a rich, carefree, happy-go-lucky second...
# ...

# %%
# getting descriptive statistics
movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean   161243.505000     34.697267      6.621150   1547.309400
# std    211422.046043    211.684175      0.766231   2648.295789
# min         5.000000      0.600000      4.600000    200.000000
# 25%     10127.750000      9.154750      6.100000    315.000000
# 50%     30002.500000     13.637500      6.600000    583.500000
# 75%    310133.500000     25.651250      7.200000   1460.000000
# max    934761.000000  10436.917000      8.700000  31917.000000

# %%
"""
This code snippet calls the `info()` method on the `movies` object. 
The `info()` method provides a summary of the DataFrame `movies`, including the column names, data types, and non-null counts.
"""
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.2+ KB

# %%
# counting number of missing values
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %% [markdown]
# Feature Selection Part

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# This line of code is selecting only the 'id', 'title', 'overview', and 'genre' columns from the 'movies' DataFrame. The result is assigned back to 'movies', effectively reducing the DataFrame to only these four columns.
movies = movies[['id', 'title', 'overview', 'genre']]movies=movies[['id', 'title', 'overview', 'genre']]

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
# This line of code is creating a new column 'tags' in the 'movies' DataFrame. The 'tags' column is a combination of the 'overview' and 'genre' columns for each movie.
movies['tags'] = movies['overview'] + movies['genre']
# Out:
# <ipython-input-69-52ba05029f8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
# This line of code is creating a new DataFrame 'new_data' by dropping the 'overview' and 'genre' columns from the 'movies' DataFrame.
new_data = movies.drop(columns=['overview', 'genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %% [markdown]
# # Text Cleaning (NLP Text Cleaning steps with NLTK)

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

def clean_text(text):
    # Check if text is not a string
    if not isinstance(text, str):
        return ""  # or some other default value like 'NaN' or None

    # Convert to lowercase
    text = text.lower()

    # Remove punctuation but keep digits
    text = re.sub(r'[^\w\s\d]', '', text)

    # Tokenize
    words = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    # Join the words back together
    text = ' '.join(words)
    return text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
new_data['tags_clean'] = new_data['tags'].apply(clean_text)

# %% [markdown]
# # Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
pip install scikit-learn

# %%
new_data['tags_clean'] = new_data['tags'].apply(clean_text)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# This line of code is initializing a CountVectorizer object 'cv' with a maximum of 10,000 features and English stop words.
cv = CountVectorizer(max_features=10000, stop_words='english')

# %%
# This line of code is fitting the CountVectorizer 'cv' to the 'tags_clean' column of the 'new_data' DataFrame and transforming the text data into a numerical vector representation. The result is converted to a NumPy array and assigned to the variable 'vector'.
vector = cv.fit_transform(new_data['tags_clean'].values.astype('U')).toarray()

# %%
new_data['tags']
# Out:
# 0       Framed in the 1940s for the double murder of h...
# 1       Raj is a rich, carefree, happy-go-lucky second...
# 2       Spanning the years 1945 to 1955, a chronicle o...
# 3       The true story of how businessman Oskar Schind...
# 4       In the continuing saga of the Corleone crime f...
#                               ...
# 9995    The story follows the adventures of Aang, a yo...
# 9996    The sharks take bite out of the East Coast whe...
# 9997    During World War II, a brave, patriotic Americ...
# 9998    A man named Farmer sets out to rescue his kidn...
# 9999    Seeking justice for his partner’s murder by an...
# Name: tags, Length: 10000, dtype: object

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.03175003, 0.02993422, ..., 0.0862796 , 0.09274778,
#         0.03745029],
#        [0.03175003, 1.        , 0.05892557, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02993422, 0.05892557, 1.        , ..., 0.        , 0.04303315,
#         0.0347524 ],
#        ...,
#        [0.0862796 , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.09274778, 0.        , 0.04303315, ..., 0.        , 1.        ,
#         0.        ],
#        [0.03745029, 0.        , 0.0347524 , ..., 0.        , 0.        ,
#         1.        ]])

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10000 non-null  int64
#  1   title       10000 non-null  object
#  2   tags        9985 non-null   object
#  3   tags_clean  10000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 312.6+ KB

# %%
# This line of code is calculating the similarity scores for the third movie (index 2) with all other movies, sorting them in descending order, and storing the sorted list of tuples in the 'distance' variable. Each tuple contains the index of the movie and its similarity score with the third movie.
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])

# This loop is iterating over the first five tuples in the 'distance' list (the five movies most similar to the third movie) and printing the title of each movie.
for i in distance[0:5]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# The Batman
# Life Is a Long Quiet River
# The Lovely Bones

# %%
# This function recommends the top 5 similar movies. It first finds the index of the input movie in the 'new_data' DataFrame. Then, it calculates the similarity scores of this movie with all other movies, sorts them in descending order, and prints the titles of the top 5 most similar movies.
def recommend(movies):
    index = new_data[new_data['title'] == movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].title)

# %%
recommend("Iron Man")
# Out:
# Iron Man
# Iron Man 2
# Banana
# The New Mutants
# Time Trap

# %%
import pickle

# %%
pickle.dump(new_data, open('movies_list.pkl', 'wb'))

# %%
pickle.dump(new_data, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies_list.pkl', 'rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
import os

# %%
print(os.getcwd())
# Out:
# /content
